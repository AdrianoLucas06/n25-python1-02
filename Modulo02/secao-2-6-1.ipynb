# %% [markdown]
# # Interação com o usuario
# ### Funçãp Input()

# %%
print("Digite sua idade")
idade = input ()
print ("Você tem " + idade + " anos.") #forma 1
# Out:
# Digite sua idade
# Você tem 28 anos.

# %%
idade = input("digite sua idade") # passando a mensagem como argumento
print("Você tem " + idade + " anos.") #forma 2
print(type(idade))  #verificando o tipo da variavel idade
# Out:
# Você tem 28 anos.

# %%
valor = input("Valor")
print("valor"+ valor)
# Out:
# valor12

# %%
# Isso não sera possivel fazer
idade = input ("Digite sua idade")
ano_nascimento = 2025 - idade # erro de tipo, idade é uma string e não um numero
print("Você nasceu em " + ano_nascimento + ".") # convertendo idade
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Isso não sera possivel fazer
#       2 idade = input ("Digite sua idade")
# ----> 3 ano_nascimento = 2025 - idade # erro de tipo, idade é uma string e não um numero
#       4 print("Você nasceu em " + ano_nascimento + ".") # convertendo idade
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
# correto
idade = int(input ("Digite sua idade"))
ano_nascimento = 2025 - idade 
print("Você nasceu em " + str(ano_nascimento) + ".") # convertendo idade
# Out:
# Você nasceu em 1997.

# %%
idade = int(input ("Digite sua idade"))
ano_nascimento = 2025 - idade 
print("Você nasceu em",ano_nascimento,".")
# Out:
# Você nasceu em 1997 .

# %%
idade = int(input ("Digite sua idade"))
ano_nascimento = 2025 - idade # convertendo o ano para str
print("Você nasceu em" +str(ano_nascimento) + ".")

# %%
# Desenvolver um programa para solicitar o valor de uma temperatura
# em graus celsius e convertela pata graus Fahrenheit.
# A Formula de conversão é:
# F = C * 9/5 + 32
celsius = float (input("Digite a temperatura em celsius: "))
fahrenheit = celsius * 9/5 + 32
print("A temperatura em Fahrenheit é: ", fahrenheit, "°F", sep="")
# Out:
# A temperatura em Fahrenheit é: 77.9°F

# %% [markdown]
# # Laboratorio 2.6.10
# ![image-2.png](attachment:image-2.png)

# %%
x = float(input("Digite o valor para x: "))
y = 1./(x + 1./(x + 1./(x + 1./x)))
print("y =", y)
# Out:
# y = 0.09901951266867294

# %%
x = float(input("Digite o valor para x: "))
y= 1/(x+1/(x+1/(x+1/x)))
print("y =",y)
# Out:
# y = 0.09901951266867294

# %% [markdown]
# # laboratorio 2.6.11
# ![image.png](attachment:image.png)

# %%
#exemplo 1 
hour = int(input("Hora de início (horas): "))
mins = int(input("Hora de início (minutos): "))
dura = int(input("Duração do evento (minutos): "))
# Escreva seu codigo aqui
tempo_total = hour * 60 + mins + dura # converte tudo para minuto
hora_final = tempo_total // 60 % 24 # pega a parte inteira da divisão
minuto_final = tempo_total % 60 # pega o resto da divisão
#imprimir o resultado em horas e minutos
print(hora_final, minuto_final, sep= ".")
# Out:
# 11.49

# %%
#exemplo 2
hour = int(input("Hora de início (horas): "))
mins = int(input("Hora de início (minutos): "))
dura = int(input("Duração do evento (minutos): "))
mins = mins + dura # encontre um total de todos os minutos
hour = hour + mins // 60 # encontre um número de horas escondido em minutos e atualize a hora
mins = mins % 60 # minutos corretos para cair no intervalo (0..59)
hour = hour % 24 # horas corretas para cair no intervalo (0..23)
print(hour, ":", mins, sep='')
